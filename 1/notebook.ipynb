# %%
import pandas as pd

# %% [markdown]
# Импортируйте библиотеку pandas, а затем загрузите датасет 2_taxi_nyc (находится в папке). Результат сохраните в переменную taxi.

# %%
df = pd.read_csv('2_taxi_nyc.csv')

# %% [markdown]
# Проверьте, сколько всего строк и столбцов имеется в датасете.

# %%
df.shape[0]
# Out:
# 29101

# %%
# pickup_dt – период с точностью до часа
# pickup_month – месяц
# borough – район Нью-Йорка, из которого был сделан заказ (5 районов + аэропорт)
# pickups – число поездок за период (час)
# hday – является ли день праздничным/выходным; Y - да,  N - нет
# spd – скорость ветра в милях в час
# vsb – видимость
# temp – температура в градусах Фаренгейта
# dewp – точка росы по Фаренгейту
# slp – давление
# pcp_01 – количество осадков за час
# pcp_06 – количество осадков за 6 часов
# pcp_24 – количество осадков за 24 часа
# sd – глубина снега в дюймах

# %% [markdown]
# Давайте посмотрим на типы колонок. Все ли из них считались правильно? Назовите тип, преобладающий в датасете.

# %%
df.head()
# Out:
#              pickup_dt pickup_month    borough  pickups hday  spd   vsb  temp  \
# 0  2015-01-01 01:00:00          Jan      Bronx      152    Y  5.0  10.0  30.0
# 1  2015-01-01 01:00:00          Jan   Brooklyn     1519    Y  5.0  10.0  30.0
# 2  2015-01-01 01:00:00          Jan        EWR        0    Y  5.0  10.0  30.0
# 3  2015-01-01 01:00:00          Jan  Manhattan     5258    Y  5.0  10.0  30.0
# 4  2015-01-01 01:00:00          Jan     Queens      405    Y  5.0  10.0  30.0
#
#    dewp     slp  pcp 01  pcp 06  pcp 24   sd
# 0   7.0  1023.5     0.0     0.0     0.0  0.0
# 1   7.0  1023.5     0.0     0.0     0.0  0.0
# 2   7.0  1023.5     0.0     0.0     0.0  0.0
# 3   7.0  1023.5     0.0     0.0     0.0  0.0
# 4   7.0  1023.5     0.0     0.0     0.0  0.0

# %%
df.dtypes
# Out:
# pickup_dt        object
# pickup_month     object
# borough          object
# pickups           int64
# hday             object
# spd             float64
# vsb             float64
# temp            float64
# dewp            float64
# slp             float64
# pcp 01          float64
# pcp 06          float64
# pcp 24          float64
# sd              float64
# dtype: object

# %%
df.dtypes.value_counts()
# Out:
# float64    9
# object     4
# int64      1
# Name: count, dtype: int64

# %% [markdown]
# даты считались как object, а не timedata
# преобладающ. тип - float64

# %% [markdown]
# переименование колонок

# %%
df = df.rename(columns=lambda x: x.replace(' ', '_'))
df.head()
# Out:
#              pickup_dt pickup_month    borough  pickups hday  spd   vsb  temp  \
# 0  2015-01-01 01:00:00          Jan      Bronx      152    Y  5.0  10.0  30.0
# 1  2015-01-01 01:00:00          Jan   Brooklyn     1519    Y  5.0  10.0  30.0
# 2  2015-01-01 01:00:00          Jan        EWR        0    Y  5.0  10.0  30.0
# 3  2015-01-01 01:00:00          Jan  Manhattan     5258    Y  5.0  10.0  30.0
# 4  2015-01-01 01:00:00          Jan     Queens      405    Y  5.0  10.0  30.0
#
#    dewp     slp  pcp_01  pcp_06  pcp_24   sd
# 0   7.0  1023.5     0.0     0.0     0.0  0.0
# 1   7.0  1023.5     0.0     0.0     0.0  0.0
# 2   7.0  1023.5     0.0     0.0     0.0  0.0
# 3   7.0  1023.5     0.0     0.0     0.0  0.0
# 4   7.0  1023.5     0.0     0.0     0.0  0.0

# %%
# df = df.rename(columns={'pcp 01': 'pcp_01','pcp 06': 'pcp_06', 'pcp 24': 'pcp_24'})

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29101 entries, 0 to 29100
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   pickup_dt     29101 non-null  object
#  1   pickup_month  29101 non-null  object
#  2   borough       26058 non-null  object
#  3   pickups       29101 non-null  int64
#  4   hday          29101 non-null  object
#  5   spd           29101 non-null  float64
#  6   vsb           29101 non-null  float64
#  7   temp          29101 non-null  float64
#  8   dewp          29101 non-null  float64
#  9   slp           29101 non-null  float64
#  10  pcp_01        29101 non-null  float64
#  11  pcp_06        29101 non-null  float64
#  12  pcp_24        29101 non-null  float64
#  13  sd            29101 non-null  float64
# dtypes: float64(9), int64(1), object(4)
# memory usage: 3.1+ MB

# %%
df.tail()
# Out:
#                  pickup_dt pickup_month        borough  pickups hday  spd  \
# 29096  2015-06-30 23:00:00          Jun            EWR        0    N  7.0
# 29097  2015-06-30 23:00:00          Jun      Manhattan     3828    N  7.0
# 29098  2015-06-30 23:00:00          Jun         Queens      580    N  7.0
# 29099  2015-06-30 23:00:00          Jun  Staten Island        0    N  7.0
# 29100  2015-06-30 23:00:00          Jun            NaN        3    N  7.0
#
#         vsb  temp  dewp     slp  pcp_01  pcp_06  pcp_24   sd
# 29096  10.0  75.0  65.0  1011.8     0.0     0.0     0.0  0.0
# 29097  10.0  75.0  65.0  1011.8     0.0     0.0     0.0  0.0
# 29098  10.0  75.0  65.0  1011.8     0.0     0.0     0.0  0.0
# 29099  10.0  75.0  65.0  1011.8     0.0     0.0     0.0  0.0
# 29100  10.0  75.0  65.0  1011.8     0.0     0.0     0.0  0.0

# %% [markdown]
# сколько поездок совершено в манхеттене

# %%
df[df.borough=='Manhattan'].shape[0]
# Out:
# 4343

# %%
df.borough.value_counts()
# Out:
# borough
# Bronx            4343
# Brooklyn         4343
# EWR              4343
# Manhattan        4343
# Queens           4343
# Staten Island    4343
# Name: count, dtype: int64

# %%
int(df['borough'].value_counts()['Manhattan'])
# Out:
# 4343

# %% [markdown]
# сколько всего поездок

# %%
df.pickups.sum()
# Out:
# 14265773

# %% [markdown]
# поездок по районам

# %%
df.groupby('borough').aggregate({'pickups': 'sum'}).sort_values('pickups', ascending=False)
# Out:
#                 pickups
# borough
# Manhattan      10367841
# Brooklyn        2321035
# Queens          1343528
# Bronx            220047
# Staten Island      6957
# EWR                 105

# %% [markdown]
# максимум район по поездкам

# %%
df.groupby('borough').agg({'pickups': 'sum'}).idxmax()
# Out:
# pickups    Manhattan
# dtype: object

# %% [markdown]
# 9) ⭐️Задание со звёздочкой!⭐️
# Еще несколько полезных методов в pandas! Возможно, в предыдущем степе вы просто посмотрели на данные или отсортировали значения. Ускорить данный процесс в дальнейшем помогут методы idxmin() и idxmax(), которые возвращают индекс минимального или максимального значения.
# Сохраните название района с наименьшим числом поездок в переменную min_pickups, применив подходящий метод.

# %%
min_pickups = df.groupby('borough').agg({'pickups': 'sum'}).idxmin()[0]
# Out:
# C:\Users\Кирилл\AppData\Local\Temp\ipykernel_17224\1734523093.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   min_pickups = df.groupby('borough').agg({'pickups': 'sum'}).idxmin()[0]

# %%
min_pickups
# Out:
# 'EWR'

# %% [markdown]
# 10) Продолжим изучение данных и посмотрим на число поездок в выходные дни. Сгруппируйте данные по двум признакам: району города и является ли день выходным (колонки borough и hday). Сравните среднее число поездок, и назовите районы, из которых по праздникам в среднем поступает больше заказов, чем в обычные дни.

# %%
df.groupby(['borough', 'hday']).agg({'pickups': 'mean'})
# Out:
#                         pickups
# borough       hday
# Bronx         N       50.771073
#               Y       48.065868
# Brooklyn      N      534.727969
#               Y      527.011976
# EWR           N        0.023467
#               Y        0.041916
# Manhattan     N     2401.302921
#               Y     2035.928144
# Queens        N      308.899904
#               Y      320.730539
# Staten Island N        1.606082
#               Y        1.497006

# %% [markdown]
# 11) Для каждого района посчитайте число поездок по месяцам. Отсортируйте полученные значения по убыванию и сохраните результирующий датафрейм в pickups_by_mon_bor. Обратите внимание, что итоговый датасет должен состоять из 3-х колонок – pickup_month, borough, pickups.

# %%
pickups_by_mon_bor = df.groupby(['borough', 'pickup_month'], as_index=False).agg({'pickups': 'sum'}).sort_values('pickups', ascending=False)
pickups_by_mon_bor
# Out:
#           borough pickup_month  pickups
# 21      Manhattan          Jun  1995388
# 23      Manhattan          May  1888800
# 19      Manhattan          Feb  1718571
# 22      Manhattan          Mar  1661261
# 18      Manhattan          Apr  1648278
# 20      Manhattan          Jan  1455543
# 9        Brooklyn          Jun   482466
# 11       Brooklyn          May   476087
# 6        Brooklyn          Apr   378095
# 10       Brooklyn          Mar   346726
# 7        Brooklyn          Feb   328650
# 8        Brooklyn          Jan   309011
# 27         Queens          Jun   286311
# 29         Queens          May   275893
# 28         Queens          Mar   219561
# 24         Queens          Apr   216857
# 25         Queens          Feb   185695
# 26         Queens          Jan   159211
# 5           Bronx          May    53037
# 3           Bronx          Jun    49006
# 0           Bronx          Apr    34617
# 4           Bronx          Mar    32232
# 1           Bronx          Feb    28694
# 2           Bronx          Jan    22461
# 33  Staten Island          Jun     1673
# 35  Staten Island          May     1517
# 30  Staten Island          Apr     1068
# 34  Staten Island          Mar      975
# 31  Staten Island          Feb      903
# 32  Staten Island          Jan      821
# 15            EWR          Jun       29
# 17            EWR          May       27
# 16            EWR          Mar       14
# 13            EWR          Feb       14
# 14            EWR          Jan       11
# 12            EWR          Apr       10

# %% [markdown]
# 12) 💀 Сложное задание! 💀
# Теперь задача посложнее! Попрактикуемся в написании собственных функций и их применении к датафрейму. Поскольку данные о поездках в Нью-Йорке, температура представлена в градусах Фаренгейта.
# Напишите функцию temp_to_celcius, которая получает на вход колонку с температурой в °F, и возвращает значения, переведенные в градусы Цельсия.

# %%
def temp_to_celsius(Fahrenheit):
    Celsius = ((Fahrenheit-32) *5.0)/(9.0)
    return Celsius
temp_to_celsius(df.temp)
# Out:
# 0        -1.111111
# 1        -1.111111
# 2        -1.111111
# 3        -1.111111
# 4        -1.111111
#            ...
# 29096    23.888889
# 29097    23.888889
# 29098    23.888889
# 29099    23.888889
# 29100    23.888889
# Name: temp, Length: 29101, dtype: float64

# %%
df.temp = df.temp.map(temp_to_celsius)
df
# Out:
#                  pickup_dt pickup_month        borough  pickups hday  spd  \
# 0      2015-01-01 01:00:00          Jan          Bronx      152    Y  5.0
# 1      2015-01-01 01:00:00          Jan       Brooklyn     1519    Y  5.0
# 2      2015-01-01 01:00:00          Jan            EWR        0    Y  5.0
# 3      2015-01-01 01:00:00          Jan      Manhattan     5258    Y  5.0
# 4      2015-01-01 01:00:00          Jan         Queens      405    Y  5.0
# ...                    ...          ...            ...      ...  ...  ...
# 29096  2015-06-30 23:00:00          Jun            EWR        0    N  7.0
# 29097  2015-06-30 23:00:00          Jun      Manhattan     3828    N  7.0
# 29098  2015-06-30 23:00:00          Jun         Queens      580    N  7.0
# 29099  2015-06-30 23:00:00          Jun  Staten Island        0    N  7.0
# 29100  2015-06-30 23:00:00          Jun            NaN        3    N  7.0
#
#         vsb       temp  dewp     slp  pcp_01  pcp_06  pcp_24   sd
# 0      10.0  -1.111111   7.0  1023.5     0.0     0.0     0.0  0.0
# 1      10.0  -1.111111   7.0  1023.5     0.0     0.0     0.0  0.0
# 2      10.0  -1.111111   7.0  1023.5     0.0     0.0     0.0  0.0
# 3      10.0  -1.111111   7.0  1023.5     0.0     0.0     0.0  0.0
# 4      10.0  -1.111111   7.0  1023.5     0.0     0.0     0.0  0.0
# ...     ...        ...   ...     ...     ...     ...     ...  ...
# 29096  10.0  23.888889  65.0  1011.8     0.0     0.0     0.0  0.0
# 29097  10.0  23.888889  65.0  1011.8     0.0     0.0     0.0  0.0
# 29098  10.0  23.888889  65.0  1011.8     0.0     0.0     0.0  0.0
# 29099  10.0  23.888889  65.0  1011.8     0.0     0.0     0.0  0.0
# 29100  10.0  23.888889  65.0  1011.8     0.0     0.0     0.0  0.0
#
# [29101 rows x 14 columns]
